# %%
import os

def total_files(folder_path):
    num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    return num_files

train_files_Apple__black_rot = "dataset_split/train/Apple__black_rot"
train_files_Apple__healthy = "dataset_split/train/Apple__healthy"
train_files_Apple__rust = "dataset_split/train/Apple__rust"
train_files_Apple__scab = "dataset_split/train/Apple__scab"
train_files_Cassava__bacterial_blight = "dataset_split/train/Cassava__bacterial_blight"
train_files_Cassava__brown_streak_disease = "dataset_split/train/Cassava__brown_streak_disease"
train_files_Cassava__green_mottle = "dataset_split/train/Cassava__green_mottle"
train_files_Cassava__healthy = "dataset_split/train/Cassava__healthy"
train_files_Cassava__mosaic_disease = "dataset_split/train/Cassava__mosaic_disease"
train_files_Cherry__healthy = "dataset_split/train/Cherry__healthy"
train_files_Cherry__powdery_mildew = "dataset_split/train/Cherry__powdery_mildew"
train_files_Chili__healthy= "dataset_split/train/Chili__healthy"
train_files_Chili__leaf_curl = "dataset_split/train/Chili__leaf_curl"
train_files_Chili__leaf_spot = "dataset_split/train/Chili__leaf_spot"
train_files_Chili__whitefly = "dataset_split/train/Chili__whitefly"
train_files_Chili__yellowish = "dataset_split/train/Chili__yellowish"
train_files_Coffee__cercospora_leaf_spot = "dataset_split/train/Coffee__cercospora_leaf_spot"
train_files_Coffee__healthy = "dataset_split/train/Coffee__healthy"
train_files_Coffee__red_spider_mite = "dataset_split/train/Coffee__red_spider_mite"
train_files_Coffee__rust = "dataset_split/train/Coffee__rust"
train_files_Corn__common_rust = "dataset_split/train/Corn__common_rust"
train_files_Corn__gray_leaf_spot = "dataset_split/train/Corn__gray_leaf_spot"
train_files_Corn__healthy = "dataset_split/train/Corn__healthy"
train_files_Corn__northern_leaf_blight = "dataset_split/train/Corn__northern_leaf_blight"
train_files_Cucumber__diseased= "dataset_split/train/Cucumber__diseased"
train_files_Cucumber__healthy = "dataset_split/train/Cucumber__healthy"
train_files_Gauva__diseased = "dataset_split/train/Gauva__diseased"
train_files_Gauva__healthy= "dataset_split/train/Gauva__healthy"
train_files_Grape__black_measles= "dataset_split/train/Grape__black_measles"
train_files_Grape__black_rot = "dataset_split/train/Grape__black_rot"
train_files_Grape__healthy = "dataset_split/train/Grape__healthy"
train_files_Grape__leaf_blight_isariopsis_leaf_spot = "dataset_split/train/Grape__leaf_blight_isariopsis_leaf_spot"
train_files_Jamun__diseased = "dataset_split/train/Jamun__diseased"
train_files_Jamun__healthy= "dataset_split/train/Jamun__healthy"
train_files_Lemon__diseased = "dataset_split/train/Lemon__diseased"
train_files_Lemon__healthy = "dataset_split/train/Lemon__healthy"
train_files_Mango__diseased= "dataset_split/train/Mango__diseased"
train_files_Mango__healthy= "dataset_split/train/Mango__healthy"
train_files_Peach__bacterial_spot = "dataset_split/train/Peach__bacterial_spot"
train_files_Peach__healthy= "dataset_split/train/Peach__healthy"
train_files_Pepper_bell__bacterial_spot = "dataset_split/train/Pepper_bell__bacterial_spot"
train_files_Pepper_bell__healthy = "dataset_split/train/Pepper_bell__healthy"
train_files_Pomegranate__diseased = "dataset_split/train/Pomegranate__diseased"
train_files_Pomegranate__healthy = "dataset_split/train/Pomegranate__healthy"
train_files_Potato__early_blight = "dataset_split/train/Potato__early_blight"
train_files_Potato__healthy = "dataset_split/train/Potato__healthy"
train_files_Potato__late_blight= "dataset_split/train/Potato__late_blight"
train_files_Rice__brown_spot = "dataset_split/train/Rice__brown_spot"
train_files_Rice__healthy= "dataset_split/train/Rice__healthy"
train_files_Rice__hispa = "dataset_split/train/Rice__hispa"
train_files_Rice__leaf_blast = "dataset_split/train/Rice__leaf_blast"
train_files_Rice__neck_blast = "dataset_split/train/Rice__neck_blast"
train_files_Soybean__bacterial_blight = "dataset_split/train/Soybean__bacterial_blight"
train_files_Soybean__caterpillar = "dataset_split/train/Soybean__caterpillar"
train_files_Soybean__diabrotica_speciosa = "dataset_split/train/Soybean__diabrotica_speciosa"
train_files_Soybean__downy_mildew = "dataset_split/train/Soybean__downy_mildew"
train_files_Soybean__healthy= "dataset_split/train/Soybean__healthy"
train_files_Soybean__mosaic_virus = "dataset_split/train/Soybean__mosaic_virus"
train_files_Soybean__powdery_mildew = "dataset_split/train/Soybean__powdery_mildew"
train_files_Soybean__rust= "dataset_split/train/Soybean__rust"
train_files_Soybean__southern_blight = "dataset_split/train/Soybean__southern_blight"
train_files_Strawberry___leaf_scorch = "dataset_split/train/Strawberry___leaf_scorch"
train_files_Strawberry__healthy = "dataset_split/train/Strawberry__healthy"
train_files_Sugarcane__bacterial_blight = "dataset_split/train/Sugarcane__bacterial_blight"
train_files_Sugarcane__healthy = "dataset_split/train/Sugarcane__healthy"
train_files_Sugarcane__red_rot= "dataset_split/train/Sugarcane__red_rot"
train_files_Sugarcane__red_stripe = "dataset_split/train/Sugarcane__red_stripe"
train_files_Sugarcane__rust = "dataset_split/train/Sugarcane__rust"
train_files_Tea__algal_leaf = "dataset_split/train/Tea__algal_leaf"
train_files_Tea__anthracnose = "dataset_split/train/Tea__anthracnose"
train_files_Tea__bird_eye_spot= "dataset_split/train/Tea__bird_eye_spot"
train_files_Tea__brown_blight = "dataset_split/train/Tea__brown_blight"
train_files_Tea__healthy = "dataset_split/train/Tea__healthy"
train_files_Tea__red_leaf_spot = "dataset_split/train/Tea__red_leaf_spot"
train_files_Tomato__bacterial_spot = "dataset_split/train/Tomato__bacterial_spot"
train_files_Tomato__early_blight = "dataset_split/train/Tomato__early_blight"
train_files_Tomato__healthy = "dataset_split/train/Tomato__healthy"
train_files_Tomato__late_blight = "dataset_split/train/Tomato__late_blight"
train_files_Tomato__leaf_mold = "dataset_split/train/Tomato__leaf_mold"
train_files_Tomato__mosaic_virus = "dataset_split/train/Tomato__mosaic_virus"
train_files_Tomato__septoria_leaf_spot = "dataset_split/train/Tomato__septoria_leaf_spot"
train_files_Tomato__target_spot = "dataset_split/train/Tomato__target_spot"
train_files_Tomato__spider_mites_two_spotted_spider_mite = "dataset_split/train/Tomato__spider_mites_two_spotted_spider_mite"
train_files_Tomato__yellow_leaf_curl_virus = "dataset_split/train/Tomato__yellow_leaf_curl_virus"
train_files_Wheat__brown_rust = "dataset_split/train/Wheat__brown_rust"
train_files_Wheat__healthy = "dataset_split/train/Wheat__healthy"
train_files_Wheat__septoria = "dataset_split/train/Wheat__septoria"
train_files_Wheat__yellow_rust = "dataset_split/train/Wheat__yellow_rust"



test_files_Apple__black_rot = "dataset_split/test/Apple__black_rot"
test_files_Apple__healthy = "dataset_split/test/Apple__healthy"
test_files_Apple__rust = "dataset_split/test/Apple__rust"
test_files_Apple__scab = "dataset_split/test/Apple__scab"
test_files_Cassava__bacterial_blight = "dataset_split/test/Cassava__bacterial_blight"
test_files_Cassava__brown_streak_disease = "dataset_split/test/Cassava__brown_streak_disease"
test_files_Cassava__green_mottle = "dataset_split/test/Cassava__green_mottle"
test_files_Cassava__healthy = "dataset_split/test/Cassava__healthy"
test_files_Cassava__mosaic_disease = "dataset_split/test/Cassava__mosaic_disease"
test_files_Cherry__healthy = "dataset_split/test/Cherry__healthy"
test_files_Cherry__powdery_mildew = "dataset_split/test/Cherry__powdery_mildew"
test_files_Chili__healthy= "dataset_split/test/Chili__healthy"
test_files_Chili__leaf_curl = "dataset_split/test/Chili__leaf_curl"
test_files_Chili__leaf_spot = "dataset_split/test/Chili__leaf_spot"
test_files_Chili__whitefly = "dataset_split/test/Chili__whitefly"
test_files_Chili__yellowish = "dataset_split/test/Chili__yellowish"
test_files_Coffee__cercospora_leaf_spot = "dataset_split/test/Coffee__cercospora_leaf_spot"
test_files_Coffee__healthy = "dataset_split/test/Coffee__healthy"
test_files_Coffee__red_spider_mite = "dataset_split/test/Coffee__red_spider_mite"
test_files_Coffee__rust = "dataset_split/test/Coffee__rust"
test_files_Corn__common_rust = "dataset_split/test/Corn__common_rust"
test_files_Corn__gray_leaf_spot = "dataset_split/test/Corn__gray_leaf_spot"
test_files_Corn__healthy = "dataset_split/test/Corn__healthy"
test_files_Corn__northern_leaf_blight = "dataset_split/test/Corn__northern_leaf_blight"
test_files_Cucumber__diseased= "dataset_split/test/Cucumber__diseased"
test_files_Cucumber__healthy = "dataset_split/test/Cucumber__healthy"
test_files_Gauva__diseased = "dataset_split/test/Gauva__diseased"
test_files_Gauva__healthy= "dataset_split/test/Gauva__healthy"
test_files_Grape__black_measles= "dataset_split/test/Grape__black_measles"
test_files_Grape__black_rot = "dataset_split/test/Grape__black_rot"
test_files_Grape__healthy = "dataset_split/test/Grape__healthy"
test_files_Grape__leaf_blight_isariopsis_leaf_spot = "dataset_split/test/Grape__leaf_blight_isariopsis_leaf_spot"
test_files_Jamun__diseased = "dataset_split/test/Jamun__diseased"
test_files_Jamun__healthy= "dataset_split/test/Jamun__healthy"
test_files_Lemon__diseased = "dataset_split/test/Lemon__diseased"
test_files_Lemon__healthy = "dataset_split/test/Lemon__healthy"
test_files_Mango__diseased= "dataset_split/test/Mango__diseased"
test_files_Mango__healthy= "dataset_split/test/Mango__healthy"
test_files_Peach__bacterial_spot = "dataset_split/test/Peach__bacterial_spot"
test_files_Peach__healthy= "dataset_split/test/Peach__healthy"
test_files_Pepper_bell__bacterial_spot = "dataset_split/test/Pepper_bell__bacterial_spot"
test_files_Pepper_bell__healthy = "dataset_split/test/Pepper_bell__healthy"
test_files_Pomegranate__diseased = "dataset_split/test/Pomegranate__diseased"
test_files_Pomegranate__healthy = "dataset_split/test/Pomegranate__healthy"
test_files_Potato__early_blight = "dataset_split/test/Potato__early_blight"
test_files_Potato__healthy = "dataset_split/test/Potato__healthy"
test_files_Potato__late_blight= "dataset_split/test/Potato__late_blight"
test_files_Rice__brown_spot = "dataset_split/test/Rice__brown_spot"
test_files_Rice__healthy= "dataset_split/test/Rice__healthy"
test_files_Rice__hispa = "dataset_split/test/Rice__hispa"
test_files_Rice__leaf_blast = "dataset_split/test/Rice__leaf_blast"
test_files_Rice__neck_blast = "dataset_split/test/Rice__neck_blast"
test_files_Soybean__bacterial_blight = "dataset_split/test/Soybean__bacterial_blight"
test_files_Soybean__caterpillar = "dataset_split/test/Soybean__caterpillar"
test_files_Soybean__diabrotica_speciosa = "dataset_split/test/Soybean__diabrotica_speciosa"
test_files_Soybean__downy_mildew = "dataset_split/test/Soybean__downy_mildew"
test_files_Soybean__healthy= "dataset_split/test/Soybean__healthy"
test_files_Soybean__mosaic_virus = "dataset_split/test/Soybean__mosaic_virus"
test_files_Soybean__powdery_mildew = "dataset_split/test/Soybean__powdery_mildew"
test_files_Soybean__rust= "dataset_split/test/Soybean__rust"
test_files_Soybean__southern_blight = "dataset_split/test/Soybean__southern_blight"
test_files_Strawberry___leaf_scorch = "dataset_split/test/Strawberry___leaf_scorch"
test_files_Strawberry__healthy = "dataset_split/test/Strawberry__healthy"
test_files_Sugarcane__bacterial_blight = "dataset_split/test/Sugarcane__bacterial_blight"
test_files_Sugarcane__healthy = "dataset_split/test/Sugarcane__healthy"
test_files_Sugarcane__red_rot= "dataset_split/test/Sugarcane__red_rot"
test_files_Sugarcane__red_stripe = "dataset_split/test/Sugarcane__red_stripe"
test_files_Sugarcane__rust = "dataset_split/test/Sugarcane__rust"
test_files_Tea__algal_leaf = "dataset_split/test/Tea__algal_leaf"
test_files_Tea__anthracnose = "dataset_split/test/Tea__anthracnose"
test_files_Tea__bird_eye_spot= "dataset_split/test/Tea__bird_eye_spot"
test_files_Tea__brown_blight = "dataset_split/test/Tea__brown_blight"
test_files_Tea__healthy = "dataset_split/test/Tea__healthy"
test_files_Tea__red_leaf_spot = "dataset_split/test/Tea__red_leaf_spot"
test_files_Tomato__bacterial_spot = "dataset_split/test/Tomato__bacterial_spot"
test_files_Tomato__early_blight = "dataset_split/test/Tomato__early_blight"
test_files_Tomato__healthy = "dataset_split/test/Tomato__healthy"
test_files_Tomato__late_blight = "dataset_split/test/Tomato__late_blight"
test_files_Tomato__leaf_mold = "dataset_split/test/Tomato__leaf_mold"
test_files_Tomato__mosaic_virus = "dataset_split/test/Tomato__mosaic_virus"
test_files_Tomato__septoria_leaf_spot = "dataset_split/test/Tomato__septoria_leaf_spot"
test_files_Tomato__target_spot = "dataset_split/test/Tomato__target_spot"
test_files_Tomato__spider_mites_two_spotted_spider_mite = "dataset_split/test/Tomato__spider_mites_two_spotted_spider_mite"
test_files_Tomato__yellow_leaf_curl_virus = "dataset_split/test/Tomato__yellow_leaf_curl_virus"
test_files_Wheat__brown_rust = "dataset_split/test/Wheat__brown_rust"
test_files_Wheat__healthy = "dataset_split/test/Wheat__healthy"
test_files_Wheat__septoria = "dataset_split/test/Wheat__septoria"
test_files_Wheat__yellow_rust = "dataset_split/test/Wheat__yellow_rust"



val_files_Apple__black_rot = "dataset_split/val/Apple__black_rot"
val_files_Apple__healthy = "dataset_split/val/Apple__healthy"
val_files_Apple__rust = "dataset_split/val/Apple__rust"
val_files_Apple__scab = "dataset_split/val/Apple__scab"
val_files_Cassava__bacterial_blight = "dataset_split/val/Cassava__bacterial_blight"
val_files_Cassava__brown_streak_disease = "dataset_split/val/Cassava__brown_streak_disease"
val_files_Cassava__green_mottle = "dataset_split/val/Cassava__green_mottle"
val_files_Cassava__healthy = "dataset_split/val/Cassava__healthy"
val_files_Cassava__mosaic_disease = "dataset_split/val/Cassava__mosaic_disease"
val_files_Cherry__healthy = "dataset_split/val/Cherry__healthy"
val_files_Cherry__powdery_mildew = "dataset_split/val/Cherry__powdery_mildew"
val_files_Chili__healthy= "dataset_split/val/Chili__healthy"
val_files_Chili__leaf_curl = "dataset_split/val/Chili__leaf_curl"
val_files_Chili__leaf_spot = "dataset_split/val/Chili__leaf_spot"
val_files_Chili__whitefly = "dataset_split/val/Chili__whitefly"
val_files_Chili__yellowish = "dataset_split/val/Chili__yellowish"
val_files_Coffee__cercospora_leaf_spot = "dataset_split/val/Coffee__cercospora_leaf_spot"
val_files_Coffee__healthy = "dataset_split/val/Coffee__healthy"
val_files_Coffee__red_spider_mite = "dataset_split/val/Coffee__red_spider_mite"
val_files_Coffee__rust = "dataset_split/val/Coffee__rust"
val_files_Corn__common_rust = "dataset_split/val/Corn__common_rust"
val_files_Corn__gray_leaf_spot = "dataset_split/val/Corn__gray_leaf_spot"
val_files_Corn__healthy = "dataset_split/val/Corn__healthy"
val_files_Corn__northern_leaf_blight = "dataset_split/val/Corn__northern_leaf_blight"
val_files_Cucumber__diseased= "dataset_split/val/Cucumber__diseased"
val_files_Cucumber__healthy = "dataset_split/val/Cucumber__healthy"
val_files_Gauva__diseased = "dataset_split/val/Gauva__diseased"
val_files_Gauva__healthy= "dataset_split/val/Gauva__healthy"
val_files_Grape__black_measles= "dataset_split/val/Grape__black_measles"
val_files_Grape__black_rot = "dataset_split/val/Grape__black_rot"
val_files_Grape__healthy = "dataset_split/val/Grape__healthy"
val_files_Grape__leaf_blight_isariopsis_leaf_spot= "dataset_split/val/Grape__leaf_blight_isariopsis_leaf_spot"
val_files_Jamun__diseased = "dataset_split/val/Jamun__diseased"
val_files_Jamun__healthy= "dataset_split/val/Jamun__healthy"
val_files_Lemon__diseased = "dataset_split/val/Lemon__diseased"
val_files_Lemon__healthy = "dataset_split/val/Lemon__healthy"
val_files_Mango__diseased= "dataset_split/val/Mango__diseased"
val_files_Mango__healthy= "dataset_split/val/Mango__healthy"
val_files_Peach__bacterial_spot = "dataset_split/val/Peach__bacterial_spot"
val_files_Peach__healthy= "dataset_split/val/Peach__healthy"
val_files_Pepper_bell__bacterial_spot = "dataset_split/val/Pepper_bell__bacterial_spot"
val_files_Pepper_bell__healthy = "dataset_split/val/Pepper_bell__healthy"
val_files_Pomegranate__diseased = "dataset_split/val/Pomegranate__diseased"
val_files_Pomegranate__healthy = "dataset_split/val/Pomegranate__healthy"
val_files_Potato__early_blight = "dataset_split/val/Potato__early_blight"
val_files_Potato__healthy = "dataset_split/val/Potato__healthy"
val_files_Potato__late_blight= "dataset_split/val/Potato__late_blight"
val_files_Rice__brown_spot = "dataset_split/val/Rice__brown_spot"
val_files_Rice__healthy= "dataset_split/val/Rice__healthy"
val_files_Rice__hispa = "dataset_split/val/Rice__hispa"
val_files_Rice__leaf_blast = "dataset_split/val/Rice__leaf_blast"
val_files_Rice__neck_blast = "dataset_split/val/Rice__neck_blast"
val_files_Soybean__bacterial_blight = "dataset_split/val/Soybean__bacterial_blight"
val_files_Soybean__caterpillar = "dataset_split/val/Soybean__caterpillar"
val_files_Soybean__diabrotica_speciosa = "dataset_split/val/Soybean__diabrotica_speciosa"
val_files_Soybean__downy_mildew = "dataset_split/val/Soybean__downy_mildew"
val_files_Soybean__healthy= "dataset_split/val/Soybean__healthy"
val_files_Soybean__mosaic_virus = "dataset_split/val/Soybean__mosaic_virus"
val_files_Soybean__powdery_mildew = "dataset_split/val/Soybean__powdery_mildew"
val_files_Soybean__rust= "dataset_split/val/Soybean__rust"
val_files_Soybean__southern_blight = "dataset_split/val/Soybean__southern_blight"
val_files_Strawberry___leaf_scorch = "dataset_split/val/Strawberry___leaf_scorch"
val_files_Strawberry__healthy = "dataset_split/val/Strawberry__healthy"
val_files_Sugarcane__bacterial_blight = "dataset_split/val/Sugarcane__bacterial_blight"
val_files_Sugarcane__healthy = "dataset_split/val/Sugarcane__healthy"
val_files_Sugarcane__red_rot= "dataset_split/val/Sugarcane__red_rot"
val_files_Sugarcane__red_stripe = "dataset_split/val/Sugarcane__red_stripe"
val_files_Sugarcane__rust = "dataset_split/val/Sugarcane__rust"
val_files_Tea__algal_leaf = "dataset_split/val/Tea__algal_leaf"
val_files_Tea__anthracnose = "dataset_split/val/Tea__anthracnose"
val_files_Tea__bird_eye_spot= "dataset_split/val/Tea__bird_eye_spot"
val_files_Tea__brown_blight = "dataset_split/val/Tea__brown_blight"
val_files_Tea__healthy = "dataset_split/val/Tea__healthy"
val_files_Tea__red_leaf_spot = "dataset_split/val/Tea__red_leaf_spot"
val_files_Tomato__bacterial_spot = "dataset_split/val/Tomato__bacterial_spot"
val_files_Tomato__early_blight = "dataset_split/val/Tomato__early_blight"
val_files_Tomato__healthy = "dataset_split/val/Tomato__healthy"
val_files_Tomato__late_blight = "dataset_split/val/Tomato__late_blight"
val_files_Tomato__leaf_mold = "dataset_split/val/Tomato__leaf_mold"
val_files_Tomato__mosaic_virus = "dataset_split/val/Tomato__mosaic_virus"
val_files_Tomato__septoria_leaf_spot = "dataset_split/val/Tomato__septoria_leaf_spot"
val_files_Tomato__target_spot = "dataset_split/val/Tomato__target_spot"
val_files_Tomato__spider_mites_two_spotted_spider_mite = "dataset_split/val/Tomato__spider_mites_two_spotted_spider_mite"
val_files_Tomato__yellow_leaf_curl_virus = "dataset_split/val/Tomato__yellow_leaf_curl_virus"
val_files_Wheat__brown_rust = "dataset_split/val/Wheat__brown_rust"
val_files_Wheat__healthy = "dataset_split/val/Wheat__healthy"
val_files_Wheat__septoria = "dataset_split/val/Wheat__septoria"
val_files_Wheat__yellow_rust = "dataset_split/val/Wheat__yellow_rust"

print("Number of leafApple__black_rot leaf images in training set",total_files(train_files_Apple__black_rot))
print("Number of leafApple__healthy leaf images in training set" , total_files(train_files_Apple__healthy))
print("Number of leafApple__rust leaf images in training set" , total_files(train_files_Apple__rust))
print("Number of leafApple__scab leaf images in training set" , total_files(train_files_Apple__scab))
print("Number of leafCassava__bacterial_blight leaf images in training set" , total_files(train_files_Cassava__bacterial_blight))
print("Number of leafCassava__brown_streak_disease leaf images in training set" , total_files(train_files_Cassava__brown_streak_disease))
print("Number of leafCassava__green_mottle leaf images in training set" , total_files(train_files_Cassava__green_mottle))
print("Number of leafCassava__healthy leaf images in training set" , total_files(train_files_Cassava__healthy))
print("Number of leafCassava__mosaic_disease leaf images in training set" , total_files(train_files_Cassava__mosaic_disease))
print("Number of leafCherry__healthy leaf images in training set" , total_files(train_files_Cherry__healthy))
print("Number of leafCherry__powdery_mildew leaf images in training set" , total_files(train_files_Cherry__powdery_mildew))
print("Number of leafChili__healthy leaf images in training set" , total_files(train_files_Chili__healthy))
print("Number of leafChili__leaf_curl leaf images in training set" , total_files(train_files_Chili__leaf_curl))
print("Number of leafChili__leaf_spot leaf images in training set" , total_files(train_files_Chili__leaf_spot))
print("Number of leafChili__whitefly leaf images in training set" , total_files(train_files_Chili__whitefly))
print("Number of leafChili__yellowish leaf images in training set" , total_files(train_files_Chili__yellowish))
print("Number of leafCoffee__cercospora_leaf_spot leaf images in training set" , total_files(train_files_Coffee__cercospora_leaf_spot))
print("Number of leafCoffee__healthy leaf images in training set" , total_files(train_files_Coffee__healthy))
print("Number of leafCoffee__red_spider_mite leaf images in training set" , total_files(train_files_Coffee__red_spider_mite))
print("Number of leafCoffee__rust leaf images in training set" , total_files(train_files_Coffee__rust))
print("Number of leafCorn__common_rust leaf images in training set" , total_files(train_files_Corn__common_rust))
print("Number of leafCorn__gray_leaf_spot leaf images in training set" , total_files(train_files_Corn__gray_leaf_spot))
print("Number of leafCorn__healthy leaf images in training set" , total_files(train_files_Corn__healthy))
print("Number of leafCorn__northern_leaf_blight leaf images in training set" , total_files(train_files_Corn__northern_leaf_blight))
print("Number of leafCucumber__diseasedleaf images in training set" , total_files(train_files_Cucumber__diseased))
print("Number of leafCucumber__healthy leaf images in training set" , total_files(train_files_Cucumber__healthy))
print("Number of leafGauva__diseased leaf images in training set" , total_files(train_files_Gauva__diseased))
print("Number of leafGauva__healthyleaf images in training set" , total_files(train_files_Gauva__healthy))
print("Number of leafGrape__black_measlesleaf images in training set" , total_files(train_files_Grape__black_measles))
print("Number of leafGrape__black_rot leaf images in training set" , total_files(train_files_Grape__black_rot))
print("Number of leafGrape__healthy leaf images in training set" , total_files(train_files_Grape__healthy))
print("Number of leafGrape__leaf_blight_isariopsis_leaf_spot leaf images in training set" , total_files(train_files_Grape__leaf_blight_isariopsis_leaf_spot))
print("Number of leafJamun__diseased leaf images in training set" , total_files(train_files_Jamun__diseased))
print("Number of leafJamun__healthyleaf images in training set" , total_files(train_files_Jamun__healthy))
print("Number of leafLemon__diseased leaf images in training set" , total_files(train_files_Lemon__diseased))
print("Number of leafLemon__healthy leaf images in training set" , total_files(train_files_Lemon__healthy))
print("Number of leafMango__diseasedleaf images in training set" , total_files(train_files_Mango__diseased))
print("Number of leafMango__healthyleaf images in training set" , total_files(train_files_Mango__healthy))
print("Number of leafPeach__bacterial_spot leaf images in training set" , total_files(train_files_Peach__bacterial_spot))
print("Number of leafPeach__healthyleaf images in training set" , total_files(train_files_Peach__healthy))
print("Number of leafPepper_bell__bacterial_spot leaf images in training set" , total_files(train_files_Pepper_bell__bacterial_spot))
print("Number of leafPepper_bell__healthy leaf images in training set" , total_files(train_files_Pepper_bell__healthy))
print("Number of leafPomegranate__diseased leaf images in training set" , total_files(train_files_Pomegranate__diseased))
print("Number of leafPomegranate__healthy leaf images in training set" , total_files(train_files_Pomegranate__healthy))
print("Number of leafPotato__early_blight leaft images in training set" ,total_files(train_files_Potato__early_blight))
print("Number of leafPotato__healthy leaf images in training set" , total_files(train_files_Potato__healthy))
print("Number of leafPotato__late_blightleaf images in training set" , total_files(train_files_Potato__late_blight))
print("Number of leafRice__brown_spot leaf images in training set" , total_files(train_files_Rice__brown_spot))
print("Number of leafRice__healthyleaf images in training set" , total_files(train_files_Rice__healthy))
print("Number of leafRice__hispa leaf images in training set" , total_files(train_files_Rice__hispa))
print("Number of leafRice__leaf_blast leaf images in training set" , total_files(train_files_Rice__leaf_blast))
print("Number of leafRice__neck_blast leaf images in training set" , total_files(train_files_Rice__neck_blast))
print("Number of leafSoybean__bacterial_blight leaf images in training set" , total_files(train_files_Soybean__bacterial_blight))
print("Number of leafSoybean__caterpillar leaf images in training set" , total_files(train_files_Soybean__caterpillar))
print("Number of leafSoybean__diabrotica_speciosa leaf images in training set" , total_files(train_files_Soybean__diabrotica_speciosa))
print("Number of leafSoybean__downy_mildew leaf images in training set" , total_files(train_files_Soybean__downy_mildew))
print("Number of leafSoybean__healthyleaf images in training set" , total_files(train_files_Soybean__healthy))
print("Number of leafSoybean__mosaic_virus leaf images in training set" , total_files(train_files_Soybean__mosaic_virus))
print("Number of leafSoybean__powdery_mildew leaf images in training set" , total_files(train_files_Soybean__powdery_mildew))
print("Number of leafSoybean__rustleaf images in training set" , total_files(train_files_Soybean__rust))
print("Number of leafSoybean__southern_blight leaf images in training set" , total_files(train_files_Soybean__southern_blight))
print("Number of leafStrawberry___leaf_scorch leaf images in training set" , total_files(train_files_Strawberry___leaf_scorch))
print("Number of leafStrawberry__healthy leaf images in training set" , total_files(train_files_Strawberry__healthy))
print("Number of leafSugarcane__bacterial_blight leaf images in training set" , total_files(train_files_Sugarcane__bacterial_blight))
print("Number of leafSugarcane__healthy leaf images in training set" , total_files(train_files_Sugarcane__healthy))
print("Number of leafSugarcane__red_rotleaf images in training set" , total_files(train_files_Sugarcane__red_rot))
print("Number of leafSugarcane__red_stripe leaf images in training set" , total_files(train_files_Sugarcane__red_stripe))
print("Number of leafSugarcane__rust leaf images in training set" , total_files(train_files_Sugarcane__rust))
print("Number of leafTea__algal_leaf leaf images in training set" , total_files(train_files_Tea__algal_leaf))
print("Number of leafTea__anthracnose leaf images in training set" , total_files(train_files_Tea__anthracnose))
print("Number of leafTea__bird_eye_spotleaf images in training set" , total_files(train_files_Tea__bird_eye_spot))
print("Number of leafTea__brown_blight leaf images in training set" , total_files(train_files_Tea__brown_blight))
print("Number of leafTea__healthy leaf images in training set" , total_files(train_files_Tea__healthy))
print("Number of leafTea__red_leaf_spot leaf images in training set" , total_files(train_files_Tea__red_leaf_spot))
print("Number of leafTomato__bacterial_spot leaf images in training set" , total_files(train_files_Tomato__bacterial_spot))
print("Number of leafTomato__early_blight leaf images in training set" , total_files(train_files_Tomato__early_blight))
print("Number of leafTomato__healthy leaf images in training set" , total_files(train_files_Tomato__healthy))
print("Number of leafTomato__late_blight leaf images in training set" , total_files(train_files_Tomato__late_blight))
print("Number of leafTomato__leaf_mold leaf images in training set" , total_files(train_files_Tomato__leaf_mold))
print("Number of leafTomato__mosaic_virus leaf images in training set" , total_files(train_files_Tomato__mosaic_virus))
print("Number of leafTomato__septoria_leaf_spot leaf images in training set" , total_files(train_files_Tomato__septoria_leaf_spot))
print("Number of leafTomato__target_spot leaf images in training set" , total_files(train_files_Tomato__target_spot))
print("Number of leafTomato__spider_mites_two_spotted_spider_mite leaf images in training set" , total_files(train_files_Tomato__spider_mites_two_spotted_spider_mite))
print("Number of leafTomato__yellow_leaf_curl_virus leaf images in training set" , total_files(train_files_Tomato__yellow_leaf_curl_virus))
print("Number of leafWheat__brown_rust leaf images in training set" , total_files(train_files_Wheat__brown_rust))
print("Number of leafWheat__healthy leaf images in training set" , total_files(train_files_Wheat__healthy))
print("Number of leafWheat__septoria leaf images in training set" , total_files(train_files_Wheat__septoria))
print("Number of leafWheat__yellow_rust leaf images in training set" , total_files(train_files_Wheat__yellow_rust))




print("========================================================")

print("Number of leafApple__black_rot leaf images in test set",total_files(test_files_Apple__black_rot))
print("Number of leafApple__healthy leaf images in test set" , total_files(test_files_Apple__healthy))
print("Number of leafApple__rust leaf images in test set" , total_files(test_files_Apple__rust))
print("Number of leafApple__scab leaf images in test set" , total_files(test_files_Apple__scab))
print("Number of leafCassava__bacterial_blight leaf images in test set" , total_files(test_files_Cassava__bacterial_blight))
print("Number of leafCassava__brown_streak_disease leaf images in test set" , total_files(test_files_Cassava__brown_streak_disease))
print("Number of leafCassava__green_mottle leaf images in test set" , total_files(test_files_Cassava__green_mottle))
print("Number of leafCassava__healthy leaf images in test set" , total_files(test_files_Cassava__healthy))
print("Number of leafCassava__mosaic_disease leaf images in test set" , total_files(test_files_Cassava__mosaic_disease))
print("Number of leafCherry__healthy leaf images in test set" , total_files(test_files_Cherry__healthy))
print("Number of leafCherry__powdery_mildew leaf images in test set" , total_files(test_files_Cherry__powdery_mildew))
print("Number of leafChili__healthy leaf images in test set" , total_files(test_files_Chili__healthy))
print("Number of leafChili__leaf_curl leaf images in test set" , total_files(test_files_Chili__leaf_curl))
print("Number of leafChili__leaf_spot leaf images in test set" , total_files(test_files_Chili__leaf_spot))
print("Number of leafChili__whitefly leaf images in test set" , total_files(test_files_Chili__whitefly))
print("Number of leafChili__yellowish leaf images in test set" , total_files(test_files_Chili__yellowish))
print("Number of leafCoffee__cercospora_leaf_spot leaf images in test set" , total_files(test_files_Coffee__cercospora_leaf_spot))
print("Number of leafCoffee__healthy leaf images in test set" , total_files(test_files_Coffee__healthy))
print("Number of leafCoffee__red_spider_mite leaf images in test set" , total_files(test_files_Coffee__red_spider_mite))
print("Number of leafCoffee__rust leaf images in test set" , total_files(test_files_Coffee__rust))
print("Number of leafCorn__common_rust leaf images in test set" , total_files(test_files_Corn__common_rust))
print("Number of leafCorn__gray_leaf_spot leaf images in test set" , total_files(test_files_Corn__gray_leaf_spot))
print("Number of leafCorn__healthy leaf images in test set" , total_files(test_files_Corn__healthy))
print("Number of leafCorn__northern_leaf_blight leaf images in test set" , total_files(test_files_Corn__northern_leaf_blight))
print("Number of leafCucumber__diseasedleaf images in test set" , total_files(test_files_Cucumber__diseased))
print("Number of leafCucumber__healthy leaf images in test set" , total_files(test_files_Cucumber__healthy))
print("Number of leafGauva__diseased leaf images in test set" , total_files(test_files_Gauva__diseased))
print("Number of leafGauva__healthyleaf images in test set" , total_files(test_files_Gauva__healthy))
print("Number of leafGrape__black_measlesleaf images in test set" , total_files(test_files_Grape__black_measles))
print("Number of leafGrape__black_rot leaf images in test set" , total_files(test_files_Grape__black_rot))
print("Number of leafGrape__healthy leaf images in test set" , total_files(test_files_Grape__healthy))
print("Number of leafGrape__leaf_blight_isariopsis_leaf_spot leaf images in test set" , total_files(test_files_Grape__leaf_blight_isariopsis_leaf_spot))
print("Number of leafJamun__diseased leaf images in test set" , total_files(test_files_Jamun__diseased))
print("Number of leafJamun__healthyleaf images in test set" , total_files(test_files_Jamun__healthy))
print("Number of leafLemon__diseased leaf images in test set" , total_files(test_files_Lemon__diseased))
print("Number of leafLemon__healthy leaf images in test set" , total_files(test_files_Lemon__healthy))
print("Number of leafMango__diseasedleaf images in test set" , total_files(test_files_Mango__diseased))
print("Number of leafMango__healthyleaf images in test set" , total_files(test_files_Mango__healthy))
print("Number of leafPeach__bacterial_spot leaf images in test set" , total_files(test_files_Peach__bacterial_spot))
print("Number of leafPeach__healthyleaf images in test set" , total_files(test_files_Peach__healthy))
print("Number of leafPepper_bell__bacterial_spot leaf images in test set" , total_files(test_files_Pepper_bell__bacterial_spot))
print("Number of leafPepper_bell__healthy leaf images in test set" , total_files(test_files_Pepper_bell__healthy))
print("Number of leafPomegranate__diseased leaf images in test set" , total_files(test_files_Pomegranate__diseased))
print("Number of leafPomegranate__healthy leaf images in test set" , total_files(test_files_Pomegranate__healthy))
print("Number of leafPotato__early_blight leaft images in test set" ,total_files(test_files_Potato__early_blight))
print("Number of leafPotato__healthy leaf images in test set" , total_files(test_files_Potato__healthy))
print("Number of leafPotato__late_blightleaf images in test set" , total_files(test_files_Potato__late_blight))
print("Number of leafRice__brown_spot leaf images in test set" , total_files(test_files_Rice__brown_spot))
print("Number of leafRice__healthyleaf images in test set" , total_files(test_files_Rice__healthy))
print("Number of leafRice__hispa leaf images in test set" , total_files(test_files_Rice__hispa))
print("Number of leafRice__leaf_blast leaf images in test set" , total_files(test_files_Rice__leaf_blast))
print("Number of leafRice__neck_blast leaf images in test set" , total_files(test_files_Rice__neck_blast))
print("Number of leafSoybean__bacterial_blight leaf images in test set" , total_files(test_files_Soybean__bacterial_blight))
print("Number of leafSoybean__caterpillar leaf images in test set" , total_files(test_files_Soybean__caterpillar))
print("Number of leafSoybean__diabrotica_speciosa leaf images in test set" , total_files(test_files_Soybean__diabrotica_speciosa))
print("Number of leafSoybean__downy_mildew leaf images in test set" , total_files(test_files_Soybean__downy_mildew))
print("Number of leafSoybean__healthyleaf images in test set" , total_files(test_files_Soybean__healthy))
print("Number of leafSoybean__mosaic_virus leaf images in test set" , total_files(test_files_Soybean__mosaic_virus))
print("Number of leafSoybean__powdery_mildew leaf images in test set" , total_files(test_files_Soybean__powdery_mildew))
print("Number of leafSoybean__rustleaf images in test set" , total_files(test_files_Soybean__rust))
print("Number of leafSoybean__southern_blight leaf images in test set" , total_files(test_files_Soybean__southern_blight))
print("Number of leafStrawberry___leaf_scorch leaf images in test set" , total_files(test_files_Strawberry___leaf_scorch))
print("Number of leafStrawberry__healthy leaf images in test set" , total_files(test_files_Strawberry__healthy))
print("Number of leafSugarcane__bacterial_blight leaf images in test set" , total_files(test_files_Sugarcane__bacterial_blight))
print("Number of leafSugarcane__healthy leaf images in test set" , total_files(test_files_Sugarcane__healthy))
print("Number of leafSugarcane__red_rotleaf images in test set" , total_files(test_files_Sugarcane__red_rot))
print("Number of leafSugarcane__red_stripe leaf images in test set" , total_files(test_files_Sugarcane__red_stripe))
print("Number of leafSugarcane__rust leaf images in test set" , total_files(test_files_Sugarcane__rust))
print("Number of leafTea__algal_leaf leaf images in test set" , total_files(test_files_Tea__algal_leaf))
print("Number of leafTea__anthracnose leaf images in test set" , total_files(test_files_Tea__anthracnose))
print("Number of leafTea__bird_eye_spotleaf images in test set" , total_files(test_files_Tea__bird_eye_spot))
print("Number of leafTea__brown_blight leaf images in test set" , total_files(test_files_Tea__brown_blight))
print("Number of leafTea__healthy leaf images in test set" , total_files(test_files_Tea__healthy))
print("Number of leafTea__red_leaf_spot leaf images in test set" , total_files(test_files_Tea__red_leaf_spot))
print("Number of leafTomato__bacterial_spot leaf images in test set" , total_files(test_files_Tomato__bacterial_spot))
print("Number of leafTomato__early_blight leaf images in test set" , total_files(test_files_Tomato__early_blight))
print("Number of leafTomato__healthy leaf images in test set" , total_files(test_files_Tomato__healthy))
print("Number of leafTomato__late_blight leaf images in test set" , total_files(test_files_Tomato__late_blight))
print("Number of leafTomato__leaf_mold leaf images in test set" , total_files(test_files_Tomato__leaf_mold))
print("Number of leafTomato__mosaic_virus leaf images in test set" , total_files(test_files_Tomato__mosaic_virus))
print("Number of leafTomato__septoria_leaf_spot leaf images in test set" , total_files(test_files_Tomato__septoria_leaf_spot))
print("Number of leafTomato__target_spot leaf images in test set" , total_files(test_files_Tomato__target_spot))
print("Number of leafTomato__spider_mites_two_spotted_spider_mite leaf images in test set" , total_files(test_files_Tomato__spider_mites_two_spotted_spider_mite))
print("Number of leafTomato__yellow_leaf_curl_virus leaf images in test set" , total_files(test_files_Tomato__yellow_leaf_curl_virus))
print("Number of leafWheat__brown_rust leaf images in test set" , total_files(test_files_Wheat__brown_rust))
print("Number of leafWheat__healthy leaf images in test set" , total_files(test_files_Wheat__healthy))
print("Number of leafWheat__septoria leaf images in test set" , total_files(test_files_Wheat__septoria))
print("Number of leafWheat__yellow_rust leaf images in test set" , total_files(test_files_Wheat__yellow_rust))

print("========================================================")

print("Number of leafApple__black_rot leaf images in val set",total_files(val_files_Apple__black_rot))
print("Number of leafApple__healthy leaf images in val set" , total_files(val_files_Apple__healthy))
print("Number of leafApple__rust leaf images in val set" , total_files(val_files_Apple__rust))
print("Number of leafApple__scab leaf images in val set" , total_files(val_files_Apple__scab))
print("Number of leafCassava__bacterial_blight leaf images in val set" , total_files(val_files_Cassava__bacterial_blight))
print("Number of leafCassava__brown_streak_disease leaf images in val set" , total_files(val_files_Cassava__brown_streak_disease))
print("Number of leafCassava__green_mottle leaf images in val set" , total_files(val_files_Cassava__green_mottle))
print("Number of leafCassava__healthy leaf images in val set" , total_files(val_files_Cassava__healthy))
print("Number of leafCassava__mosaic_disease leaf images in val set" , total_files(val_files_Cassava__mosaic_disease))
print("Number of leafCherry__healthy leaf images in val set" , total_files(val_files_Cherry__healthy))
print("Number of leafCherry__powdery_mildew leaf images in val set" , total_files(val_files_Cherry__powdery_mildew))
print("Number of leafChili__healthy leaf images in val set" , total_files(val_files_Chili__healthy))
print("Number of leafChili__leaf_curl leaf images in val set" , total_files(val_files_Chili__leaf_curl))
print("Number of leafChili__leaf_spot leaf images in val set" , total_files(val_files_Chili__leaf_spot))
print("Number of leafChili__whitefly leaf images in val set" , total_files(val_files_Chili__whitefly))
print("Number of leafChili__yellowish leaf images in val set" , total_files(val_files_Chili__yellowish))
print("Number of leafCoffee__cercospora_leaf_spot leaf images in val set" , total_files(val_files_Coffee__cercospora_leaf_spot))
print("Number of leafCoffee__healthy leaf images in val set" , total_files(val_files_Coffee__healthy))
print("Number of leafCoffee__red_spider_mite leaf images in val set" , total_files(val_files_Coffee__red_spider_mite))
print("Number of leafCoffee__rust leaf images in val set" , total_files(val_files_Coffee__rust))
print("Number of leafCorn__common_rust leaf images in val set" , total_files(val_files_Corn__common_rust))
print("Number of leafCorn__gray_leaf_spot leaf images in val set" , total_files(val_files_Corn__gray_leaf_spot))
print("Number of leafCorn__healthy leaf images in val set" , total_files(val_files_Corn__healthy))
print("Number of leafCorn__northern_leaf_blight leaf images in val set" , total_files(val_files_Corn__northern_leaf_blight))
print("Number of leafCucumber__diseasedleaf images in val set" , total_files(val_files_Cucumber__diseased))
print("Number of leafCucumber__healthy leaf images in val set" , total_files(val_files_Cucumber__healthy))
print("Number of leafGauva__diseased leaf images in val set" , total_files(val_files_Gauva__diseased))
print("Number of leafGauva__healthyleaf images in val set" , total_files(val_files_Gauva__healthy))
print("Number of leafGrape__black_measlesleaf images in val set" , total_files(val_files_Grape__black_measles))
print("Number of leafGrape__black_rot leaf images in val set" , total_files(val_files_Grape__black_rot))
print("Number of leafGrape__healthy leaf images in val set" , total_files(val_files_Grape__healthy))
print("Number of leafGrape__leaf_blight_isariopsis_leaf_spot leaf images in val set" , total_files(val_files_Grape__leaf_blight_isariopsis_leaf_spot))
print("Number of leafJamun__diseased leaf images in val set" , total_files(val_files_Jamun__diseased))
print("Number of leafJamun__healthyleaf images in val set" , total_files(val_files_Jamun__healthy))
print("Number of leafLemon__diseased leaf images in val set" , total_files(val_files_Lemon__diseased))
print("Number of leafLemon__healthy leaf images in val set" , total_files(val_files_Lemon__healthy))
print("Number of leafMango__diseasedleaf images in val set" , total_files(val_files_Mango__diseased))
print("Number of leafMango__healthyleaf images in val set" , total_files(val_files_Mango__healthy))
print("Number of leafPeach__bacterial_spot leaf images in val set" , total_files(val_files_Peach__bacterial_spot))
print("Number of leafPeach__healthyleaf images in val set" , total_files(val_files_Peach__healthy))
print("Number of leafPepper_bell__bacterial_spot leaf images in val set" , total_files(val_files_Pepper_bell__bacterial_spot))
print("Number of leafPepper_bell__healthy leaf images in val set" , total_files(val_files_Pepper_bell__healthy))
print("Number of leafPomegranate__diseased leaf images in val set" , total_files(val_files_Pomegranate__diseased))
print("Number of leafPomegranate__healthy leaf images in val set" , total_files(val_files_Pomegranate__healthy))
print("Number of leafPotato__early_blight leaft images in val set" ,total_files(val_files_Potato__early_blight))
print("Number of leafPotato__healthy leaf images in val set" , total_files(val_files_Potato__healthy))
print("Number of leafPotato__late_blightleaf images in val set" , total_files(val_files_Potato__late_blight))
print("Number of leafRice__brown_spot leaf images in val set" , total_files(val_files_Rice__brown_spot))
print("Number of leafRice__healthyleaf images in val set" , total_files(val_files_Rice__healthy))
print("Number of leafRice__hispa leaf images in val set" , total_files(val_files_Rice__hispa))
print("Number of leafRice__leaf_blast leaf images in val set" , total_files(val_files_Rice__leaf_blast))
print("Number of leafRice__neck_blast leaf images in val set" , total_files(val_files_Rice__neck_blast))
print("Number of leafSoybean__bacterial_blight leaf images in val set" , total_files(val_files_Soybean__bacterial_blight))
print("Number of leafSoybean__caterpillar leaf images in val set" , total_files(val_files_Soybean__caterpillar))
print("Number of leafSoybean__diabrotica_speciosa leaf images in val set" , total_files(val_files_Soybean__diabrotica_speciosa))
print("Number of leafSoybean__downy_mildew leaf images in val set" , total_files(val_files_Soybean__downy_mildew))
print("Number of leafSoybean__healthyleaf images in val set" , total_files(val_files_Soybean__healthy))
print("Number of leafSoybean__mosaic_virus leaf images in val set" , total_files(val_files_Soybean__mosaic_virus))
print("Number of leafSoybean__powdery_mildew leaf images in val set" , total_files(val_files_Soybean__powdery_mildew))
print("Number of leafSoybean__rustleaf images in val set" , total_files(val_files_Soybean__rust))
print("Number of leafSoybean__southern_blight leaf images in val set" , total_files(val_files_Soybean__southern_blight))
print("Number of leafStrawberry___leaf_scorch leaf images in val set" , total_files(val_files_Strawberry___leaf_scorch))
print("Number of leafStrawberry__healthy leaf images in val set" , total_files(val_files_Strawberry__healthy))
print("Number of leafSugarcane__bacterial_blight leaf images in val set" , total_files(val_files_Sugarcane__bacterial_blight))
print("Number of leafSugarcane__healthy leaf images in val set" , total_files(val_files_Sugarcane__healthy))
print("Number of leafSugarcane__red_rotleaf images in val set" , total_files(val_files_Sugarcane__red_rot))
print("Number of leafSugarcane__red_stripe leaf images in val set" , total_files(val_files_Sugarcane__red_stripe))
print("Number of leafSugarcane__rust leaf images in val set" , total_files(val_files_Sugarcane__rust))
print("Number of leafTea__algal_leaf leaf images in val set" , total_files(val_files_Tea__algal_leaf))
print("Number of leafTea__anthracnose leaf images in val set" , total_files(val_files_Tea__anthracnose))
print("Number of leafTea__bird_eye_spotleaf images in val set" , total_files(val_files_Tea__bird_eye_spot))
print("Number of leafTea__brown_blight leaf images in val set" , total_files(val_files_Tea__brown_blight))
print("Number of leafTea__healthy leaf images in val set" , total_files(val_files_Tea__healthy))
print("Number of leafTea__red_leaf_spot leaf images in val set" , total_files(val_files_Tea__red_leaf_spot))
print("Number of leafTomato__bacterial_spot leaf images in val set" , total_files(val_files_Tomato__bacterial_spot))
print("Number of leafTomato__early_blight leaf images in val set" , total_files(val_files_Tomato__early_blight))
print("Number of leafTomato__healthy leaf images in val set" , total_files(val_files_Tomato__healthy))
print("Number of leafTomato__late_blight leaf images in val set" , total_files(val_files_Tomato__late_blight))
print("Number of leafTomato__leaf_mold leaf images in val set" , total_files(val_files_Tomato__leaf_mold))
print("Number of leafTomato__mosaic_virus leaf images in val set" , total_files(val_files_Tomato__mosaic_virus))
print("Number of leafTomato__septoria_leaf_spot leaf images in val set" , total_files(val_files_Tomato__septoria_leaf_spot))
print("Number of leafTomato__target_spot leaf images in val set" , total_files(val_files_Tomato__target_spot))
print("Number of leafTomato__spider_mites_two_spotted_spider_mite leaf images in val set" , total_files(val_files_Tomato__spider_mites_two_spotted_spider_mite))
print("Number of leafTomato__yellow_leaf_curl_virus leaf images in val set" , total_files(val_files_Tomato__yellow_leaf_curl_virus))
print("Number of leafWheat__brown_rust leaf images in val set" , total_files(val_files_Wheat__brown_rust))
print("Number of leafWheat__healthy leaf images in val set" , total_files(val_files_Wheat__healthy))
print("Number of leafWheat__septoria leaf images in val set" , total_files(val_files_Wheat__septoria))
print("Number of leafWheat__yellow_rust leaf images in val set" , total_files(val_files_Wheat__yellow_rust))
# Out:
# Number of leafApple__black_rot leaf images in training set 200
# Number of leafApple__healthy leaf images in training set 200
# Number of leafApple__rust leaf images in training set 200
# Number of leafApple__scab leaf images in training set 200
# Number of leafCassava__bacterial_blight leaf images in training set 196
# Number of leafCassava__brown_streak_disease leaf images in training set 200
# Number of leafCassava__green_mottle leaf images in training set 198
# Number of leafCassava__healthy leaf images in training set 200
# Number of leafCassava__mosaic_disease leaf images in training set 200
# Number of leafCherry__healthy leaf images in training set 199
# Number of leafCherry__powdery_mildew leaf images in training set 200
# Number of leafChili__healthy leaf images in training set 70
# Number of leafChili__leaf_curl leaf images in training set 70
# Number of leafChili__leaf_spot leaf images in training set 70
# Number of leafChili__whitefly leaf images in training set 70
# ...

# %%
from PIL import Image
import IPython.display as display

image_path = 'dataset_split/train/Apple__healthy/0b00a1a8-b525-4392-bb6c-3ffb7d824bee___RS_HL 7904.JPG'


with open(image_path, 'rb') as f:
    display.display(display.Image(data=f.read(), width=500))

# %%
image_path = 'dataset_split/train/Apple__rust/1a67f47d-d35d-4c47-a336-af8ec6141113___FREC_C.Rust 4404.JPG'
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)
with open(image_path, 'rb') as f:
    display.display(display.Image(data=f.read(), width=500))

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory('dataset_split/train',
                                                    target_size=(225, 225),
                                                    batch_size=32,
                                                    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory('dataset_split/val',
                                                        target_size=(225, 225),
                                                        batch_size=32,
                                                        class_mode='categorical')
# Out:
# Found 15746 images belonging to 88 classes.
# Found 8393 images belonging to 88 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense


model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(225, 225, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(88, activation='softmax'))
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_generator,
                    batch_size=16,
                    epochs=5,
                    validation_data=validation_generator,
                    validation_batch_size=16
                    )
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.0780 - loss: 4.2498
# C:\Users\USER\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 1993s 4s/step - accuracy: 0.0781 - loss: 4.2483 - val_accuracy: 0.2462 - val_loss: 2.6877
# Epoch 2/5
# ...

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import seaborn as sns
sns.set_theme()
sns.set_context("poster")

figure(figsize=(25, 25), dpi=100)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.save("my_model.keras")

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array

def preprocess_image(image_path, target_size=(225, 225)):
    img = load_img(image_path, target_size=target_size)
    x = img_to_array(img)
    x = x.astype('float32') / 255.
    x = np.expand_dims(x, axis=0)
    return x

# Example usage
x = preprocess_image('dataset_split/test/Cassava__brown_streak_disease/130508321.jpg')

# %%
predictions = model.predict(x)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# array([3.10656567e-09, 1.71465793e-11, 4.16010804e-03, 3.95175093e-08,
#        1.73718221e-02, 2.06516072e-01, 1.50652165e-02, 5.66112816e-01,
#        1.42803445e-01, 1.28747524e-09, 2.06203617e-06, 3.75232380e-03,
#        6.43241801e-04, 7.09718559e-04, 5.99858395e-05, 5.47841750e-03,
#        3.66778909e-06, 1.24897881e-04, 7.47731465e-05, 1.67812861e-04,
#        1.83469179e-04, 1.49985135e-06, 1.00185325e-05, 2.03256218e-06,
#        3.95463893e-08, 1.47804022e-02, 1.02456943e-09, 1.11981845e-16,
#        1.43305020e-04, 3.74440278e-04, 9.28422105e-06, 1.93443801e-02,
#        5.29854049e-07, 9.21759863e-07, 1.34167459e-08, 2.61813629e-13,
#        2.05943193e-10, 7.74307268e-12, 2.95343145e-08, 2.15377385e-19,
#        3.16568679e-04, 3.10740973e-07, 7.31382051e-22, 1.52515355e-18,
#        4.13959560e-06, 1.39371863e-07, 5.01755665e-07, 9.31068289e-09,
#        4.88985068e-12, 1.65840743e-19, 9.41807188e-11, 9.80852076e-18,
# ...

# %%
labels = train_generator.class_indices
labels = {v: k for k, v in labels.items()}
labels
# Out:
# {0: 'Apple__black_rot',
#  1: 'Apple__healthy',
#  2: 'Apple__rust',
#  3: 'Apple__scab',
#  4: 'Cassava__bacterial_blight',
#  5: 'Cassava__brown_streak_disease',
#  6: 'Cassava__green_mottle',
#  7: 'Cassava__healthy',
#  8: 'Cassava__mosaic_disease',
#  9: 'Cherry__healthy',
#  10: 'Cherry__powdery_mildew',
#  11: 'Chili__healthy',
#  12: 'Chili__leaf_curl',
#  13: 'Chili__leaf_spot',
#  14: 'Chili__whitefly',
#  15: 'Chili__yellowish',
#  16: 'Coffee__cercospora_leaf_spot',
#  17: 'Coffee__healthy',
#  18: 'Coffee__red_spider_mite',
#  19: 'Coffee__rust',
#  20: 'Corn__common_rust',
#  21: 'Corn__gray_leaf_spot',
#  22: 'Corn__healthy',
#  23: 'Corn__northern_leaf_blight',
#  24: 'Cucumber__diseased',
#  25: 'Cucumber__healthy',
#  26: 'Gauva__diseased',
#  27: 'Gauva__healthy',
#  28: 'Grape__black_measles',
#  29: 'Grape__black_rot',
#  30: 'Grape__healthy',
#  31: 'Grape__leaf_blight_isariopsis_leaf_spot',
#  32: 'Jamun__diseased',
#  33: 'Jamun__healthy',
# ...

# %%
predicted_label = labels[np.argmax(predictions)]
print(predicted_label)
# Out:
# Cassava__healthy
